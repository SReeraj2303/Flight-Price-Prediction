# %%
import numpy as np
import pandas as pd
df=pd.read_excel("/content/Data_Train.xlsx")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
dfe=pd.read_excel("/content/Test_set.xlsx")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
dff=df.append(dfe)

# %%
dff.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
dff.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
ts=dff.Total_Stops.value_counts().sort_values(ascending=False).reset_index()
ts
# Out:
#       index  Total_Stops
# 0    1 stop         7056
# 1  non-stop         4340
# 2   2 stops         1899
# 3   3 stops           56
# 4   4 stops            2

# %%
import matplotlib.pyplot as plt
plt.bar(x=ts['index'],height=ts['Total_Stops'],color='blue')
# Out:
# <BarContainer object of 5 artists>

# %%
dff['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
Top_carriers=np.array(dff['Airline'].value_counts(sort=True))
label=['Indigo','Air India','Jet Airways','SpiceJet','Multiple carriers', 'GoAir', 'Vistara', 'Air Asia','Vistara Premium economy', 'Jet Airways Business','Multiple carriers Premium economy', 'Trujet']

# %%
plt.rcParams["figure.figsize"]=(16,8)
plt.pie(Top_carriers,labels=label,autopct='%1.1F%%')
plt.legend(labels=label,bbox_to_anchor=(1,1))
plt.title("Top_carriers")
# Out:
# Text(0.5, 1.0, 'Top_carriers')

# %%
import seaborn as sns
sns.histplot(dff,x="Price",kde=True,hue='Airline')

# %%
dff.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
flight_code=dff.Route.value_counts().head(15).sort_values(ascending=False)
flight_code
# Out:
# DEL → BOM → COK          3000
# BLR → DEL                1941
# CCU → BOM → BLR          1232
# CCU → BLR                 896
# BOM → HYD                 785
# CCU → DEL → BLR           689
# BLR → BOM → DEL           509
# MAA → CCU                 456
# DEL → HYD → COK           411
# DEL → JAI → BOM → COK     314
# DEL → BLR → COK           287
# DEL → COK                 262
# DEL → AMD → BOM → COK     246
# DEL → MAA → COK           190
# DEL → IDR → BOM → COK     117
# Name: Route, dtype: int64

# %%
flight_code=dff.Route.value_counts().head(15).sort_values(ascending=False)
flight_code.plot(kind='bar')
plt.title('Most Frequent Flights',fontsize=12)
plt.xlabel('Airline',fontsize=12)
plt.ylabel('Count',fontsize=12)
# Out:
# Text(0, 0.5, 'Count')

# %%
dff['Date']=dff['Date_of_Journey'].str.split('/').str[0]
dff['Month']=dff['Date_of_Journey'].str.split('/').str[1]
dff['Year']=dff['Date_of_Journey'].str.split('/').str[2]

# %%
dff
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
dff['Date']=dff['Date'].astype(int)
dff['Month']=dff['Month'].astype(int)
dff['Year']=dff['Year'].astype(int)

# %%
dff.drop('Date_of_Journey',axis=1,inplace=True)

# %%
dff
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
dff['Arrival_Time']=dff['Arrival_Time'].str.split(' ').str[0]

# %%
dff['Arrival_hour']=dff['Arrival_Time'].str.split(':').str[0]
dff['Arrival_minutes']=dff['Arrival_Time'].str.split(':').str[1]

# %%
dff
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
dff.drop('Arrival_Time',axis=1,inplace=True)

# %%
dff['Dep_Time']=dff['Dep_Time'].str.split(' ').str[0]

# %%
dff['Dep_hour']=dff['Dep_Time'].str.split(':').str[0]
dff['Dep_minutes']=dff['Dep_Time'].str.split(':').str[1]

# %%
dff['Dep_hour']=dff['Dep_hour'].astype(int)
dff['Dep_minutes']=dff['Dep_minutes'].astype(int)

# %%
dff.drop('Dep_Time',axis=1,inplace=True)
dff
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
# ...

# %%
dff['Total_Stops']=dff['Total_Stops'].map({'non-stop':0,'1stop':1,'2stop':2,'3stop':3,'4stop':4,'nan':2})

# %%
dff['Total_Stops'].isna().sum()
# Out:
# 9014

# %%
dff.drop('Route',axis=1,inplace=True)

# %%
dff['duration_hour']=dff['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
dff[dff['duration_hour']=='5m']
# Out:
#         Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 6474  Air India  Mumbai   Hyderabad       5m          NaN         No info
# 2660  Air India  Mumbai   Hyderabad       5m          NaN         No info
#
#         Price  Date  Month  Year Arrival_hour Arrival_minutes  Dep_hour  \
# 6474  17327.0     6      3  2019           16              55        16
# 2660      NaN    12      3  2019           16              55        16
#
#       Dep_minutes duration_hour
# 6474           50            5m
# 2660           50            5m

# %%
dff.drop(6474,axis=0,inplace=True)
dff.drop(2660,axis=0,inplace=True)
dff
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          NaN
# 2           Jet Airways     Delhi      Cochin      19h          NaN
# 3                IndiGo   Kolkata    Banglore   5h 25m          NaN
# 4                IndiGo  Banglore   New Delhi   4h 45m          NaN
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          NaN
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          NaN
# 2669          Air India     Delhi      Cochin  15h 15m          NaN
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          NaN
#
#      Additional_Info    Price  Date  Month  Year Arrival_hour Arrival_minutes  \
# ...

# %%
dff['duration_hour']=dff['duration_hour'].astype(int)

# %%
dff.drop('Duration',axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
dff['Airline']=labelencoder.fit_transform(dff['Airline'])
dff['Source']=labelencoder.fit_transform(dff['Source'])
dff['Destination']=labelencoder.fit_transform(dff['Destination'])
dff['Additional_Info']=labelencoder.fit_transform(dff['Additional_Info'])

# %%
dff.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  Date  \
# 0        3       0            5          0.0                8   3897.0    24
# 1        1       3            0          NaN                8   7662.0     1
# 2        4       2            1          NaN                8  13882.0     9
# 3        3       3            0          NaN                8   6218.0    12
# 4        3       0            5          NaN                8  13302.0     1
#
#    Month  Year Arrival_hour Arrival_minutes  Dep_hour  Dep_minutes  \
# 0      3  2019           01              10        22           20
# 1      5  2019           13              15         5           50
# 2      6  2019           04              25         9           25
# 3      5  2019           23              30        18            5
# 4      3  2019           21              35        16           50
#
#    duration_hour
# 0              2
# 1              7
# 2             19
# 3              5
# ...

# %%
dff.isna().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Total_Stops        9011
# Additional_Info       0
# Price              2670
# Date                  0
# Month                 0
# Year                  0
# Arrival_hour          0
# Arrival_minutes       0
# Dep_hour              0
# Dep_minutes           0
# duration_hour         0
# dtype: int64

# %%
dff.dropna(inplace=True)

# %%
dff.isna().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Total_Stops        0
# Additional_Info    0
# Price              0
# Date               0
# Month              0
# Year               0
# Arrival_hour       0
# Arrival_minutes    0
# Dep_hour           0
# Dep_minutes        0
# duration_hour      0
# dtype: int64

# %%
dff.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Additional_Info',
#        'Price', 'Date', 'Month', 'Year', 'Arrival_hour', 'Arrival_minutes',
#        'Dep_hour', 'Dep_minutes', 'duration_hour'],
#       dtype='object')

# %%
old_cols=dff.columns.values

# %%
new_cols=['Airline', 'Source', 'Destination', 'Total_Stops', 'Additional_Info','Date', 'Month', 'Year', 'Arrival_hour', 'Arrival_minutes','Dep_hour', 'Dep_minutes', 'duration_hour','Price']
dff=dff.reindex(columns=new_cols)

# %%
dff
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Date  \
# 0            3       0            5          0.0                8    24
# 5            8       3            0          0.0                8    24
# 11           3       3            0          0.0                8    18
# 12           1       1            4          0.0                8    24
# 14           3       3            0          0.0                8    24
# ...        ...     ...          ...          ...              ...   ...
# 10677        8       0            2          0.0                7    21
# 10678        0       3            0          0.0                8     9
# 10679        1       3            0          0.0                8    27
# 10680        4       0            2          0.0                8    27
# 10681       10       0            5          0.0                8     1
#
#        Month  Year Arrival_hour Arrival_minutes  Dep_hour  Dep_minutes  \
# ...

# %%
x=dff.iloc[:,:-1].values
y=dff.iloc[:,-1].values
x
# Out:
# array([[3, 0, 5, ..., 22, 20, 2],
#        [8, 3, 0, ..., 9, 0, 2],
#        [3, 3, 0, ..., 20, 20, 2],
#        ...,
#        [1, 3, 0, ..., 20, 45, 2],
#        [4, 0, 2, ..., 8, 20, 3],
#        [10, 0, 5, ..., 11, 30, 2]], dtype=object)

# %%
y
# Out:
# array([ 3897.,  3873.,  4174., ...,  4145.,  7229., 12648.])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
print(x_train)
# Out:
# [[8 3 0 ... 22 20 2]
#  [0 0 5 ... 23 25 2]
#  [4 0 2 ... 17 45 3]
#  ...
#  [3 0 2 ... 18 55 2]
#  [3 1 4 ... 5 15 2]
#  [0 3 0 ... 10 20 2]]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
print(x_train)
# Out:
# [[ 1.32348604  0.88280416 -1.45709304 ...  1.48482119 -0.28200757
#    0.07751749]
#  [-1.47922402 -0.97214758  1.89919425 ...  1.64871303 -0.00850837
#    0.07751749]
#  [-0.07786899 -0.97214758 -0.11457813 ...  0.66536197  1.08548845
#    1.86407621]
#  ...
#  [-0.42820775 -0.97214758 -0.11457813 ...  0.82925381  1.63248685
#    0.07751749]
#  [-0.42820775 -0.35383034  1.22793679 ... -1.30134014 -0.55550677
#    0.07751749]
#  [-1.47922402  0.88280416 -1.45709304 ... -0.48188093 -0.28200757
#    0.07751749]]

# %%
from sklearn.linear_model import LinearRegression
classifier=LinearRegression()
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
print(y_pred)
# Out:
# [6649.30259033 3295.24761089 4388.29276141 ... 4748.49064939 6817.5935093
#  6301.19935759]

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,r2_score

# %%
df1=pd.DataFrame({'Actual value':y_test,'predicted_value':y_pred})
df1
# Out:
#       Actual value  predicted_value
# 0           6144.0      6649.302590
# 1           3210.0      3295.247611
# 2           3311.0      4388.292761
# 3           3943.0      4547.271760
# 4           8040.0      3745.152218
# ...            ...              ...
# 1043        5706.0      6740.895306
# 1044        2227.0      4195.008555
# 1045        4804.0      4748.490649
# 1046        7295.0      6817.593509
# 1047        3597.0      6301.199358
#
# [1048 rows x 2 columns]

# %%
print("mean_absolute_percentage_error :",mean_absolute_percentage_error(y_test,y_pred))
print("mean_squared_error :",mean_squared_error(y_test,y_pred))
print("r2_score :",r2_score(y_test,y_pred))
# Out:
# mean_absolute_percentage_error : 0.2542901076565089
# mean_squared_error : 3224064.363932909
# r2_score : 0.22809152407950317
